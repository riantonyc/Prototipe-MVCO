# %%
# main.py
import os
import json
from google import genai
from dotenv import load_dotenv

# Load environment (.env)
load_dotenv()

# Client otomatis membaca GEMINI_API_KEY
client = genai.Client()


# Fungsi membaca semua file JSON dalam folder SaveJson/
def load_multiple_json(folder_path="SaveJson"):
    combined_data = {}

    # Pastikan folder ada
    if not os.path.exists(folder_path):
        print(f"Folder '{folder_path}' tidak ditemukan!")
        return combined_data

    # Membaca semua file json
    for file in os.listdir(folder_path):
        if file.endswith(".json"):
            file_path = os.path.join(folder_path, file)
            try:
                with open(file_path, "r", encoding="utf-8") as f:
                    combined_data[file] = json.load(f)
            except Exception as e:
                print(f"Gagal membaca {file}: {e}")

    return combined_data


# ------------------------------------------------------------
# Fungsi untuk bertanya ke Gemini
# ------------------------------------------------------------
def ask_gemini(question, context_json):
    prompt = f"""
Kamu adalah AI yang memahami data berikut (berasal dari banyak file JSON):

{json.dumps(context_json, indent=2)}

Jawablah pertanyaan berikut berdasarkan data di atas:

Pertanyaan:
{question}
"""

    response = client.models.generate_content(
        model="gemini-2.0-flash",
        contents=prompt
    )

    return response.text


# ------------------------------------------------------------
# Chatbox CLI
# ------------------------------------------------------------
def chatbox():
    print("=== Chatbox AI – Pembaca Banyak JSON (Folder: SaveJson/) ===")

    context_json = load_multiple_json("SaveJson")

    if not context_json:
        print("❌ Tidak ada file JSON ditemukan dalam folder SaveJson/")
        return

    print(f"✔ {len(context_json)} file JSON berhasil dimuat!")
    print("Ketik 'exit' untuk keluar.\n")

    while True:
        question = input("Anda: ")

        if question.lower() in ["exit", "quit", "keluar"]:
            print("Keluar dari chatbox...")
            break

        answer = ask_gemini(question, context_json)
        print(f"\nAI: {answer}\n")



# Main Program
if __name__ == "__main__":
    chatbox()
# Out:
# === Chatbox AI – Pembaca Banyak JSON (Folder: SaveJson/) ===
# ✔ 3 file JSON berhasil dimuat!
# Ketik 'exit' untuk keluar.
#
#
# AI: Oke, saya mengerti Anda ingin saya memberikan rangkuman data yang saya miliki. Berikut adalah rangkuman singkatnya:
#
# **Data Prediksi:**
#
# *   Data prediksi tersedia untuk tanggal 13 November 2025 dan 7 Desember 2025, dengan *timestamp* yang berbeda.
# *   Model yang digunakan adalah: *weather*, *road*, *equipment*, *vessel*, *logistics*, dan *production*.
# *   Setiap model memberikan prediksi dengan probabilitas tertentu berdasarkan *input* yang relevan untuk model tersebut. Contoh:
#     *   Model *weather* memprediksi "Safe" berdasarkan temperatur, kelembapan, curah hujan, dll.
#     *   Model *road* memprediksi "Operational" berdasarkan jenis permukaan, kondisi, kepadatan lubang, dll.
#     *   Model *equipment* memprediksi "0" (mungkin menandakan kondisi normal) berdasarkan suhu mesin, tekanan oli, dll.
#     *   Model *vessel* memprediksi "On Time" berdasarkan waktu penundaan, jenis kargo, berat muatan, dll.
#     *   Model *logistics* memprediksi "Low" (mungkin risiko rendah) berdasarkan tanggal, kode rute, lokasi asal, dll.
#     *   Model *production* memprediksi "Low" berdasarkan tanggal, ID mesin, shift, dll.
#
# **Data Rekomendasi:**
#
# *   Terdapat rekomendasi terkait dengan prediksi untuk tanggal 13 November 2025.
# *   Setiap rekomendasi memiliki ID unik, *timestamp*, model yang terkait, prediksi, probabilitas, *sorted labels*, *inputs*, rekomendasi (*primary, alternative, mitigation*), status, *assigned reviewers*, versi, riwayat *review*, dan waktu *update* terakhir.
# *   Rekomendasi dihasilkan oleh Gemini, tetapi mengalami *error* karena Gemini tidak mengembalikan JSON yang valid dan saya hanya memiliki *raw string JSON* yang tidak diparsing.
# *   Beberapa rekomendasi telah di-*review* dan disetujui oleh *mine\_planner* dan *shipping\_planner*.
# *   Status rekomendasi bervariasi: *final\_approved* atau *pending\_review\_shipping\_planner* dan *pending_review_mine_planner*.
# *   *Review* dilakukan oleh *mine\_planner* dan *shipping\_planner*. Mereka memberikan komentar seperti "lanjutkan".
#
# **Data Review:**
#
# *   Terdapat data *review* terpisah yang mencatat ID *review*, ID rekomendasi, peran *reviewer*, nama *reviewer*, tindakan (*approve*), komentar, dan *timestamp*.
#
# **Kesimpulan:**
#
# Data ini memberikan gambaran tentang proses prediksi dan rekomendasi yang digunakan dalam suatu operasi, mungkin di bidang pertambangan atau logistik. Terdapat alur kerja *review* yang melibatkan *mine\_planner* dan *shipping\_planner*. Namun, perlu diperhatikan bahwa rekomendasi yang dihasilkan oleh Gemini mengalami *error* dan tidak dapat diproses secara otomatis.
#
# Apakah ada aspek spesifik dari data ini yang ingin Anda ketahui lebih detail?
#
#
#
# AI: Berdasarkan data yang ada, berikut adalah analisis kondisi jalan:
#
# *   **Waktu:** Terdapat dua catatan kondisi jalan, masing-masing pada tanggal 2025-11-13 11:18:48 dan 2025-12-07 00:20:14. Kondisi jalan yang dilaporkan sama pada kedua waktu tersebut.
# *   **Prediksi:** Model `road` memprediksi kondisi jalan "Operational".
# *   **Probabilitas:** Probabilitas jalan beroperasi adalah 53%, lebih tinggi dari "Closed" (32%) dan "Severely Damaged" (15%).
# *   **Input Kondisi Jalan:**
#     *   Surface Type: Asphalt
#     *   Surface Condition: Wet
#     *   Pothole Density: 0.3
#     *   Flood Level: 0.1 meter
#     *   Traffic Density: 0.7
#     *   Accident Count: 1
#     *   Dust Level: 45 PPM
#     *   Ground Vibration: 2.1 mm/s
#     *   Road Temperature: 35°C
#     *   Rainfall: 4.5 mm
#     *   Soil Moisture: 35%
#
# **Kesimpulan:**
#
# Secara umum, kondisi jalan diprediksi "Operational". Meskipun demikian, ada beberapa faktor yang perlu diperhatikan:
#
# *   **Permukaan jalan basah** dan **kepadatan lalu lintas tinggi** (0.7) dapat meningkatkan risiko kecelakaan.
# *   **Ketinggian air 0.1 meter** menunjukkan potensi banjir, meskipun belum membahayakan.
# *   **Kepadatan lubang 0.3** perlu dipantau dan diperbaiki untuk mencegah kerusakan kendaraan.
# *   **Sudah ada 1 kecelakaan** yang tercatat, yang menunjukkan perlu adanya kewaspadaan ekstra.
# *   **Tingkat debu 45 PPM** perlu diperhatikan karena berpotensi mengganggu visibilitas.
# *   **Curah hujan 4.5 mm**
#
# **Rekomendasi Tambahan (dari data yang tersedia):**
#
# Berdasarkan rekomendasi yang dihasilkan oleh model, beberapa tindakan yang disarankan adalah:
#
# *   Lanjutkan operasi dengan pemantauan ketat.
# *   Perlambat kecepatan kendaraan.
# *   Tingkatkan kewaspadaan pengemudi.
# *   Pantau ketinggian air banjir secara berkala.
# *   Periksa kondisi lubang secara berkala dan lakukan perbaikan.
# *   Semprotkan air untuk mengurangi debu.
# *   Pastikan drainase berfungsi dengan baik.
#
# Rekomendasi-rekomendasi tersebut memberikan panduan yang lebih spesifik berdasarkan kondisi jalan yang ada.
#
#
# Keluar dari chatbox...
